# %% [markdown]
# <a href="https://colab.research.google.com/github/nourhan254/Autism-/blob/main/Untitled26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import zipfile
import numpy as np
import pandas as pd
import nibabel as nib
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv3D, MaxPooling3D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
# Out:
# Mounted at /content/drive

# %%
# Define paths
base_path = '/content/drive/MyDrive/ADHD1/'

# Unzip the files (only need to do this once)
def unzip_files():
    sites = ['Peking_1', 'NeuroIMAGE', 'KKI']
    for site in sites:
        zip_path = os.path.join(base_path, f'{site}.zip')
        extract_path = os.path.join(base_path, site)
        if not os.path.exists(extract_path):
            with zipfile.ZipFile(zip_path, 'r') as zip_ref:
                zip_ref.extractall(extract_path)

unzip_files()

# %%
def load_phenotypic_data():
    # Load each site's phenotypic data
    peking_pheno = pd.read_csv(os.path.join(base_path, 'Peking_1_phenotypic.csv'))
    neuro_pheno = pd.read_csv(os.path.join(base_path, 'NeuroIMAGE_phenotypic.csv'))
    kki_pheno = pd.read_csv(os.path.join(base_path, 'KKI_phenotypic.csv'))

    # Standardize column names across sites
    def standardize_columns(df):
        # Create mapping of possible column names to standard names
        column_map = {
            'subject': ['subject', 'SUBID', 'Subject', 'ID', 'participant_id'],
            'diagnosis': ['diagnosis', 'DX', 'ADHD', 'label', 'group'],
            'site': ['site', 'dataset', 'Site']
        }

        # Find matching columns
        standardized_df = pd.DataFrame()
        for standard_name, possible_names in column_map.items():
            for name in possible_names:
                if name in df.columns:
                    standardized_df[standard_name] = df[name]
                    break

        return standardized_df

    # Apply standardization to each dataframe
    peking_pheno = standardize_columns(peking_pheno)
    neuro_pheno = standardize_columns(neuro_pheno)
    kki_pheno = standardize_columns(kki_pheno)

    # Add site identifiers if not present
    if 'site' not in peking_pheno.columns:
        peking_pheno['site'] = 'Peking'
    if 'site' not in neuro_pheno.columns:
        neuro_pheno['site'] = 'NeuroIMAGE'
    if 'site' not in kki_pheno.columns:
        kki_pheno['site'] = 'KKI'

    # Combine all phenotypic data
    combined_pheno = pd.concat([peking_pheno, neuro_pheno, kki_pheno], ignore_index=True)

    # First clean the diagnosis column (convert to string for consistent handling)
    combined_pheno['diagnosis'] = combined_pheno['diagnosis'].astype(str).str.lower().str.strip()

    # Create mapping dictionary for diagnosis values
    diagnosis_map = {
        '1': 1, 'adhd': 1, 'adhd-i': 1, 'adhd-c': 1, 'adhd-h': 1,
        '0': 0, 'control': 0, 'healthy': 0, 'typical': 0, 'normal': 0
    }

    # Map diagnosis values
    combined_pheno['diagnosis'] = combined_pheno['diagnosis'].map(diagnosis_map)

    # Drop rows with NaN in diagnosis (couldn't be mapped)
    combined_pheno = combined_pheno.dropna(subset=['diagnosis'])

    # Convert diagnosis to integer
    combined_pheno['diagnosis'] = combined_pheno['diagnosis'].astype(int)

    # Verify we have reasonable data
    print("Diagnosis value counts:")
    print(combined_pheno['diagnosis'].value_counts())

    return combined_pheno

pheno_data = load_phenotypic_data()
# Out:
# Diagnosis value counts:
# diagnosis
# 0    145
# 1     41
# Name: count, dtype: int64

# %%
def inspect_csv_files():
    files = {
        'Peking': 'Peking_1_phenotypic.csv',
        'NeuroIMAGE': 'NeuroIMAGE_phenotypic.csv',
        'KKI': 'KKI_phenotypic.csv'
    }

    for site, filename in files.items():
        filepath = os.path.join(base_path, filename)
        df = pd.read_csv(filepath)
        print(f"\n{site} file columns:")
        print(df.columns.tolist())
        print("\nFirst 3 rows:")
        print(df.head(3))

inspect_csv_files()
# Out:
# Peking file columns:
# ['ScanDir ID', 'Site', 'Gender', 'Age', 'Handedness', 'DX', 'Secondary Dx ', 'ADHD Measure', 'ADHD Index', 'Inattentive', 'Hyper/Impulsive', 'IQ Measure', 'Verbal IQ', 'Performance IQ', 'Full2 IQ', 'Full4 IQ', 'Med Status', 'QC_Rest_1', 'QC_Rest_2', 'QC_Rest_3', 'QC_Rest_4', 'QC_Anatomical_1', 'QC_Anatomical_2']
#
# First 3 rows:
#    ScanDir ID  Site  Gender    Age  Handedness  DX Secondary Dx   \
# 0     1056121     1       1  13.92           1   0           NaN
# 1     1113498     1       0  14.83           1   0           NaN
# 2     1133221     1       1  12.33           1   1           ODD
#
#    ADHD Measure  ADHD Index  Inattentive  ...  Performance IQ  Full2 IQ  \
# 0             1        30.0         15.0  ...             136       NaN
# 1             1        20.0         11.0  ...             135       NaN
# 2             1        64.0         32.0  ...             108       NaN
#
#    Full4 IQ  Med Status  QC_Rest_1  QC_Rest_2  QC_Rest_3  QC_Rest_4  \
# 0       135           1          1        NaN        NaN        NaN
# 1       133           1          1        NaN        NaN        NaN
# 2       113           2          1        NaN        NaN        NaN
#
#    QC_Anatomical_1  QC_Anatomical_2
# 0                1              NaN
# 1                1              NaN
# 2                1              NaN
#
# [3 rows x 23 columns]
#
# NeuroIMAGE file columns:
# ['ScanDir ID', 'Site', 'Gender', 'Age', 'Handedness', 'DX', 'Secondary Dx ', 'ADHD Measure', 'ADHD Index', 'Inattentive', 'Hyper/Impulsive', 'IQ Measure', 'Verbal IQ', 'Performance IQ', 'Full2 IQ', 'Full4 IQ', 'Med Status', 'QC_Rest_1', 'QC_Rest_2', 'QC_Rest_3', 'QC_Rest_4', 'QC_Anatomical_1', 'QC_Anatomical_2']
#
# First 3 rows:
#    ScanDir ID  Site  Gender    Age  Handedness  DX  Secondary Dx   \
# 0     1017176     4       0  11.66           1   0            NaN
# 1     1125505     4       1  19.30           1   0            NaN
# 2     1208586     4       1  20.89           1   2            NaN
#
#    ADHD Measure  ADHD Index  Inattentive  ...  Performance IQ  Full2 IQ  \
# 0           NaN         NaN          NaN  ...             NaN       NaN
# 1           NaN         NaN          NaN  ...             NaN       NaN
# 2           NaN         NaN          NaN  ...             NaN       NaN
#
#    Full4 IQ  Med Status  QC_Rest_1  QC_Rest_2  QC_Rest_3  QC_Rest_4  \
# 0       NaN         NaN          1        NaN        NaN        NaN
# 1       NaN         NaN          1        NaN        NaN        NaN
# 2       NaN         NaN          1        NaN        NaN        NaN
#
#    QC_Anatomical_1  QC_Anatomical_2
# 0                1              NaN
# 1                1              NaN
# 2                1              NaN
#
# [3 rows x 23 columns]
#
# KKI file columns:
# ['ScanDir ID', 'Site', 'Gender', 'Age', 'Handedness', 'DX', 'Secondary Dx ', 'ADHD Measure', 'ADHD Index', 'Inattentive', 'Hyper/Impulsive', 'IQ Measure', 'Verbal IQ', 'Performance IQ', 'Full2 IQ', 'Full4 IQ', 'Med Status', 'QC_Rest_1', 'QC_Rest_2', 'QC_Rest_3', 'QC_Rest_4', 'QC_Anatomical_1', 'QC_Anatomical_2']
#
# First 3 rows:
#    ScanDir ID  Site  Gender    Age  Handedness  DX Secondary Dx   \
# 0     2371032     3       0  10.73           1   0           NaN
# 1     2026113     3       0  12.99           1   1           NaN
# 2     3434578     3       0   8.12           1   0           NaN
#
#    ADHD Measure  ADHD Index  Inattentive  ...  Performance IQ  Full2 IQ  \
# 0             2          47           55  ...             119       NaN
# 1             2          90           89  ...             108       NaN
# 2             2          42           42  ...              98       NaN
#
#    Full4 IQ  Med Status  QC_Rest_1  QC_Rest_2  QC_Rest_3  QC_Rest_4  \
# 0       122           1          1        NaN        NaN        NaN
# 1       106           1          1        NaN        NaN        NaN
# 2        89           1          1        NaN        NaN        NaN
#
#    QC_Anatomical_1  QC_Anatomical_2
# 0                1              NaN
# 1                1              NaN
# 2                1              NaN
#
# [3 rows x 23 columns]

# %%
def load_phenotypic_data():
    # Define the exact file names we know you have
    files = {
        'Peking': 'Peking_1_phenotypic.csv',
        'NeuroIMAGE': 'NeuroIMAGE_phenotypic.csv',
        'KKI': 'KKI_phenotypic.csv'
    }

    dfs = []

    for site, filename in files.items():
        filepath = os.path.join(base_path, filename)

        # Check if file exists before trying to read it
        if not os.path.exists(filepath):
            print(f"Warning: File not found - {filepath}")
            continue

        df = pd.read_csv(filepath)
        print(f"\nLoaded {site} data with shape: {df.shape}")

        # Create standardized dataframe with the columns we know exist
        standardized_df = pd.DataFrame()

        # Use 'ScanDir ID' as subject ID
        if 'ScanDir ID' in df.columns:
            standardized_df['subject'] = df['ScanDir ID'].astype(str).str.strip()
        else:
            print(f"Could not find subject column in {site} data")
            continue

        # Use 'DX' as diagnosis
        if 'DX' in df.columns:
            standardized_df['diagnosis'] = df['DX']
        else:
            print(f"Could not find diagnosis column in {site} data")
            continue

        # Add site identifier
        standardized_df['site'] = site

        dfs.append(standardized_df)

    if not dfs:
        raise ValueError("No valid data files could be loaded")

    # Combine all data
    combined = pd.concat(dfs, ignore_index=True)

    # Clean diagnosis data
    combined['diagnosis'] = combined['diagnosis'].astype(str).str.upper().str.strip()

    # Map to binary classification (ADHD=1, Control=0)
    diagnosis_map = {
        '1': 1, 'ADHD': 1, 'ADHD-I': 1, 'ADHD-C': 1, 'ADHD-H': 1, 'CASE': 1,
        '0': 0, 'CONTROL': 0, 'HEALTHY': 0, 'TYPICAL': 0, 'NORMAL': 0, 'TD': 0
    }

    combined['diagnosis'] = combined['diagnosis'].map(diagnosis_map)

    # Drop rows with invalid diagnosis
    combined = combined.dropna(subset=['diagnosis'])
    combined['diagnosis'] = combined['diagnosis'].astype(int)

    print("\nFinal dataset summary:")
    print(f"Total subjects: {len(combined)}")
    print("Diagnosis counts:")
    print(combined['diagnosis'].value_counts())
    print("\nSites distribution:")
    print(combined['site'].value_counts())

    return combined

pheno_data = load_phenotypic_data()
# Out:
# Loaded Peking data with shape: (85, 23)
#
# Loaded NeuroIMAGE data with shape: (48, 23)
#
# Loaded KKI data with shape: (83, 23)
#
# Final dataset summary:
# Total subjects: 186
# Diagnosis counts:
# diagnosis
# 0    145
# 1     41
# Name: count, dtype: int64
#
# Sites distribution:
# site
# KKI           77
# Peking        68
# NeuroIMAGE    41
# Name: count, dtype: int64

# %%
# Out:
# Testing image paths for 5 random subjects:
# ✗ Peking subject 3004580: NOT FOUND
# ✗ Peking subject 2123983: NOT FOUND
# ✗ Peking subject 1056121: NOT FOUND
# ✗ KKI subject 8083695: NOT FOUND
# ✗ KKI subject 2138826: NOT FOUND

# %%
def explore_directory(path, max_depth=3):
    print(f"\nExploring: {path}")
    for root, dirs, files in os.walk(path):
        level = root.replace(path, '').count(os.sep)
        if level < max_depth:
            indent = ' ' * 4 * level
            print(f"{indent}{os.path.basename(root)}/")
            subindent = ' ' * 4 * (level + 1)
            for f in files[:5]:  # Print first 5 files
                print(f"{subindent}{f}")
            if len(files) > 5:
                print(f"{subindent}... and {len(files)-5} more")

explore_directory(base_path)
# Out:
# Exploring: /content/drive/MyDrive/ADHD1/
# /
#     KKI_phenotypic.csv
#     NeuroIMAGE_phenotypic.csv
#     Peking_1_TestRelease_phenotypic.csv
#     Peking_1_phenotypic.csv
#     KKI.zip
#     ... and 2 more
# Peking_1/
#     Peking_1/
#         anat_processed_paths.csv
#         dataset_description.json
#         filtered_participants.tsv
#         filtered_paths.csv
#         missing_participants_ids.csv
#         ... and 4 more
#         sub-1038415/
#             normalized_resampled_128_sub-1038415_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1038415_T1_biascorr_brain.nii
#             resampled_128_sub-1038415_T1_biascorr_brain.nii
#             resampled_224_sub-1038415_T1_biascorr_brain.nii
#             sub-1038415_T1_biascorr_brain.nii
#         sub-1056121/
#             normalized_resampled_128_sub-1056121_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1056121_T1_biascorr_brain.nii
#             resampled_128_sub-1056121_T1_biascorr_brain.nii
#             resampled_224_sub-1056121_T1_biascorr_brain.nii
#             sub-1056121_T1_biascorr_brain.nii
#         sub-1113498/
#             normalized_resampled_128_sub-1113498_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1113498_T1_biascorr_brain.nii
#             resampled_128_sub-1113498_T1_biascorr_brain.nii
#             resampled_224_sub-1113498_T1_biascorr_brain.nii
#             sub-1113498_T1_biascorr_brain.nii
#         sub-1133221/
#             normalized_resampled_128_sub-1133221_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1133221_T1_biascorr_brain.nii
#             resampled_128_sub-1133221_T1_biascorr_brain.nii
#             resampled_224_sub-1133221_T1_biascorr_brain.nii
#             sub-1133221_T1_biascorr_brain.nii
#         sub-1139030/
#             normalized_resampled_128_sub-1139030_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1139030_T1_biascorr_brain.nii
#             resampled_128_sub-1139030_T1_biascorr_brain.nii
#             resampled_224_sub-1139030_T1_biascorr_brain.nii
#             sub-1139030_T1_biascorr_brain.nii
#         sub-1186237/
#             normalized_resampled_128_sub-1186237_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1186237_T1_biascorr_brain.nii
#             resampled_128_sub-1186237_T1_biascorr_brain.nii
#             resampled_224_sub-1186237_T1_biascorr_brain.nii
#             sub-1186237_T1_biascorr_brain.nii
#         sub-1201251/
#             normalized_resampled_128_sub-1201251_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1201251_T1_biascorr_brain.nii
#             resampled_128_sub-1201251_T1_biascorr_brain.nii
#             resampled_224_sub-1201251_T1_biascorr_brain.nii
#             sub-1201251_T1_biascorr_brain.nii
#         sub-1240299/
#             normalized_resampled_128_sub-1240299_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1240299_T1_biascorr_brain.nii
#             resampled_128_sub-1240299_T1_biascorr_brain.nii
#             resampled_224_sub-1240299_T1_biascorr_brain.nii
#             sub-1240299_T1_biascorr_brain.nii
#         sub-1245758/
#             normalized_resampled_128_sub-1245758_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1245758_T1_biascorr_brain.nii
#             resampled_128_sub-1245758_T1_biascorr_brain.nii
#             resampled_224_sub-1245758_T1_biascorr_brain.nii
#             sub-1245758_T1_biascorr_brain.nii
#         sub-1253411/
#             normalized_resampled_128_sub-1253411_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1253411_T1_biascorr_brain.nii
#             resampled_128_sub-1253411_T1_biascorr_brain.nii
#             resampled_224_sub-1253411_T1_biascorr_brain.nii
#             sub-1253411_T1_biascorr_brain.nii
#         sub-1258069/
#             normalized_resampled_128_sub-1258069_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1258069_T1_biascorr_brain.nii
#             resampled_128_sub-1258069_T1_biascorr_brain.nii
#             resampled_224_sub-1258069_T1_biascorr_brain.nii
#             sub-1258069_T1_biascorr_brain.nii
#         sub-1282248/
#             normalized_resampled_128_sub-1282248_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1282248_T1_biascorr_brain.nii
#             resampled_128_sub-1282248_T1_biascorr_brain.nii
#             resampled_224_sub-1282248_T1_biascorr_brain.nii
#             sub-1282248_T1_biascorr_brain.nii
#         sub-1302449/
#             normalized_resampled_128_sub-1302449_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1302449_T1_biascorr_brain.nii
#             resampled_128_sub-1302449_T1_biascorr_brain.nii
#             resampled_224_sub-1302449_T1_biascorr_brain.nii
#             sub-1302449_T1_biascorr_brain.nii
#         sub-1391181/
#             normalized_resampled_128_sub-1391181_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1391181_T1_biascorr_brain.nii
#             resampled_128_sub-1391181_T1_biascorr_brain.nii
#             resampled_224_sub-1391181_T1_biascorr_brain.nii
#             sub-1391181_T1_biascorr_brain.nii
#         sub-1408093/
#             normalized_resampled_128_sub-1408093_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1408093_T1_biascorr_brain.nii
#             resampled_128_sub-1408093_T1_biascorr_brain.nii
#             resampled_224_sub-1408093_T1_biascorr_brain.nii
#             sub-1408093_T1_biascorr_brain.nii
#         sub-1419103/
#             normalized_resampled_128_sub-1419103_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1419103_T1_biascorr_brain.nii
#             resampled_128_sub-1419103_T1_biascorr_brain.nii
#             resampled_224_sub-1419103_T1_biascorr_brain.nii
#             sub-1419103_T1_biascorr_brain.nii
#         sub-1469171/
#             normalized_resampled_128_sub-1469171_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1469171_T1_biascorr_brain.nii
#             resampled_128_sub-1469171_T1_biascorr_brain.nii
#             resampled_224_sub-1469171_T1_biascorr_brain.nii
#             sub-1469171_T1_biascorr_brain.nii
#         sub-1517058/
#             normalized_resampled_128_sub-1517058_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1517058_T1_biascorr_brain.nii
#             resampled_128_sub-1517058_T1_biascorr_brain.nii
#             resampled_224_sub-1517058_T1_biascorr_brain.nii
#             sub-1517058_T1_biascorr_brain.nii
#         sub-1561488/
#             normalized_resampled_128_sub-1561488_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1561488_T1_biascorr_brain.nii
#             resampled_128_sub-1561488_T1_biascorr_brain.nii
#             resampled_224_sub-1561488_T1_biascorr_brain.nii
#             sub-1561488_T1_biascorr_brain.nii
#         sub-1581470/
#             normalized_resampled_128_sub-1581470_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1581470_T1_biascorr_brain.nii
#             resampled_128_sub-1581470_T1_biascorr_brain.nii
#             resampled_224_sub-1581470_T1_biascorr_brain.nii
#             sub-1581470_T1_biascorr_brain.nii
#         sub-1686092/
#             normalized_resampled_128_sub-1686092_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1686092_T1_biascorr_brain.nii
#             resampled_128_sub-1686092_T1_biascorr_brain.nii
#             resampled_224_sub-1686092_T1_biascorr_brain.nii
#             sub-1686092_T1_biascorr_brain.nii
#         sub-1689948/
#             normalized_resampled_128_sub-1689948_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1689948_T1_biascorr_brain.nii
#             resampled_128_sub-1689948_T1_biascorr_brain.nii
#             resampled_224_sub-1689948_T1_biascorr_brain.nii
#             sub-1689948_T1_biascorr_brain.nii
#         sub-1784368/
#             normalized_resampled_128_sub-1784368_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1784368_T1_biascorr_brain.nii
#             resampled_128_sub-1784368_T1_biascorr_brain.nii
#             resampled_224_sub-1784368_T1_biascorr_brain.nii
#             sub-1784368_T1_biascorr_brain.nii
#         sub-1791543/
#             normalized_resampled_128_sub-1791543_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1791543_T1_biascorr_brain.nii
#             resampled_128_sub-1791543_T1_biascorr_brain.nii
#             resampled_224_sub-1791543_T1_biascorr_brain.nii
#             sub-1791543_T1_biascorr_brain.nii
#         sub-1805037/
#             normalized_resampled_128_sub-1805037_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1805037_T1_biascorr_brain.nii
#             resampled_128_sub-1805037_T1_biascorr_brain.nii
#             resampled_224_sub-1805037_T1_biascorr_brain.nii
#             sub-1805037_T1_biascorr_brain.nii
#         sub-1849382/
#             normalized_resampled_128_sub-1849382_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1849382_T1_biascorr_brain.nii
#             resampled_128_sub-1849382_T1_biascorr_brain.nii
#             resampled_224_sub-1849382_T1_biascorr_brain.nii
#             sub-1849382_T1_biascorr_brain.nii
#         sub-1854691/
#             normalized_resampled_128_sub-1854691_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1854691_T1_biascorr_brain.nii
#             resampled_128_sub-1854691_T1_biascorr_brain.nii
#             resampled_224_sub-1854691_T1_biascorr_brain.nii
#             sub-1854691_T1_biascorr_brain.nii
#         sub-1875711/
#             normalized_resampled_128_sub-1875711_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1875711_T1_biascorr_brain.nii
#             resampled_128_sub-1875711_T1_biascorr_brain.nii
#             resampled_224_sub-1875711_T1_biascorr_brain.nii
#             sub-1875711_T1_biascorr_brain.nii
#         sub-1879542/
#             normalized_resampled_128_sub-1879542_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1879542_T1_biascorr_brain.nii
#             resampled_128_sub-1879542_T1_biascorr_brain.nii
#             resampled_224_sub-1879542_T1_biascorr_brain.nii
#             sub-1879542_T1_biascorr_brain.nii
#         sub-1883688/
#             normalized_resampled_128_sub-1883688_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1883688_T1_biascorr_brain.nii
#             resampled_128_sub-1883688_T1_biascorr_brain.nii
#             resampled_224_sub-1883688_T1_biascorr_brain.nii
#             sub-1883688_T1_biascorr_brain.nii
#         sub-1912810/
#             normalized_resampled_128_sub-1912810_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1912810_T1_biascorr_brain.nii
#             resampled_128_sub-1912810_T1_biascorr_brain.nii
#             resampled_224_sub-1912810_T1_biascorr_brain.nii
#             sub-1912810_T1_biascorr_brain.nii
#         sub-1947991/
#             normalized_resampled_128_sub-1947991_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1947991_T1_biascorr_brain.nii
#             resampled_128_sub-1947991_T1_biascorr_brain.nii
#             resampled_224_sub-1947991_T1_biascorr_brain.nii
#             sub-1947991_T1_biascorr_brain.nii
#         sub-1951511/
#             normalized_resampled_128_sub-1951511_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1951511_T1_biascorr_brain.nii
#             resampled_128_sub-1951511_T1_biascorr_brain.nii
#             resampled_224_sub-1951511_T1_biascorr_brain.nii
#             sub-1951511_T1_biascorr_brain.nii
#         sub-1985430/
#             normalized_resampled_128_sub-1985430_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1985430_T1_biascorr_brain.nii
#             resampled_128_sub-1985430_T1_biascorr_brain.nii
#             resampled_224_sub-1985430_T1_biascorr_brain.nii
#             sub-1985430_T1_biascorr_brain.nii
#         sub-2024999/
#             normalized_resampled_128_sub-2024999_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2024999_T1_biascorr_brain.nii
#             resampled_128_sub-2024999_T1_biascorr_brain.nii
#             resampled_224_sub-2024999_T1_biascorr_brain.nii
#             sub-2024999_T1_biascorr_brain.nii
#         sub-2051479/
#             normalized_resampled_128_sub-2051479_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2051479_T1_biascorr_brain.nii
#             resampled_128_sub-2051479_T1_biascorr_brain.nii
#             resampled_224_sub-2051479_T1_biascorr_brain.nii
#             sub-2051479_T1_biascorr_brain.nii
#         sub-2081754/
#             normalized_resampled_128_sub-2081754_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2081754_T1_biascorr_brain.nii
#             resampled_128_sub-2081754_T1_biascorr_brain.nii
#             resampled_224_sub-2081754_T1_biascorr_brain.nii
#             sub-2081754_T1_biascorr_brain.nii
#         sub-2101067/
#             normalized_resampled_128_sub-2101067_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2101067_T1_biascorr_brain.nii
#             resampled_128_sub-2101067_T1_biascorr_brain.nii
#             resampled_224_sub-2101067_T1_biascorr_brain.nii
#             sub-2101067_T1_biascorr_brain.nii
#         sub-2106109/
#             normalized_resampled_128_sub-2106109_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2106109_T1_biascorr_brain.nii
#             resampled_128_sub-2106109_T1_biascorr_brain.nii
#             resampled_224_sub-2106109_T1_biascorr_brain.nii
#             sub-2106109_T1_biascorr_brain.nii
#         sub-2123983/
#             normalized_resampled_128_sub-2123983_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2123983_T1_biascorr_brain.nii
#             resampled_128_sub-2123983_T1_biascorr_brain.nii
#             resampled_224_sub-2123983_T1_biascorr_brain.nii
#             sub-2123983_T1_biascorr_brain.nii
#         sub-2174595/
#             normalized_resampled_128_sub-2174595_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2174595_T1_biascorr_brain.nii
#             resampled_128_sub-2174595_T1_biascorr_brain.nii
#             resampled_224_sub-2174595_T1_biascorr_brain.nii
#             sub-2174595_T1_biascorr_brain.nii
#         sub-2196753/
#             normalized_resampled_128_sub-2196753_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2196753_T1_biascorr_brain.nii
#             resampled_128_sub-2196753_T1_biascorr_brain.nii
#             resampled_224_sub-2196753_T1_biascorr_brain.nii
#             sub-2196753_T1_biascorr_brain.nii
#         sub-2240562/
#             normalized_resampled_128_sub-2240562_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2240562_T1_biascorr_brain.nii
#             resampled_128_sub-2240562_T1_biascorr_brain.nii
#             resampled_224_sub-2240562_T1_biascorr_brain.nii
#             sub-2240562_T1_biascorr_brain.nii
#         sub-2249443/
#             normalized_resampled_128_sub-2249443_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2249443_T1_biascorr_brain.nii
#             resampled_128_sub-2249443_T1_biascorr_brain.nii
#             resampled_224_sub-2249443_T1_biascorr_brain.nii
#             sub-2249443_T1_biascorr_brain.nii
#         sub-2266806/
#             normalized_resampled_128_sub-2266806_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2266806_T1_biascorr_brain.nii
#             resampled_128_sub-2266806_T1_biascorr_brain.nii
#             resampled_224_sub-2266806_T1_biascorr_brain.nii
#             sub-2266806_T1_biascorr_brain.nii
#         sub-2275786/
#             normalized_resampled_128_sub-2275786_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2275786_T1_biascorr_brain.nii
#             resampled_128_sub-2275786_T1_biascorr_brain.nii
#             resampled_224_sub-2275786_T1_biascorr_brain.nii
#             sub-2275786_T1_biascorr_brain.nii
#         sub-2342030/
#             normalized_resampled_128_sub-2342030_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2342030_T1_biascorr_brain.nii
#             resampled_128_sub-2342030_T1_biascorr_brain.nii
#             resampled_224_sub-2342030_T1_biascorr_brain.nii
#             sub-2342030_T1_biascorr_brain.nii
#         sub-2367157/
#             normalized_resampled_128_sub-2367157_T1_biascorr_brain.nii
#             resampled_128_sub-2367157_T1_biascorr_brain.nii
#             sub-2367157_T1_biascorr_brain.nii
#         sub-2380326/
#             normalized_resampled_128_sub-2380326_T1_biascorr_brain.nii
#         sub-2380967/
#         sub-2408774/
#         sub-2411995/
#         sub-2427408/
#         sub-2443191/
#         sub-2488729/
#         sub-2505328/
#         sub-2511886/
#         sub-2528407/
#         sub-2535087/
#         sub-2538839/
#         sub-2591713/
#         sub-2599965/
#         sub-2628237/
#         sub-2697768/
#         sub-2703336/
#         sub-2714224/
#         sub-2833684/
#         sub-2872641/
#         sub-2897046/
#         sub-2910270/
#         sub-3004580/
#         sub-3086074/
#         sub-3107623/
#         sub-3124419/
#         sub-3169448/
#         sub-3212536/
#         sub-3233028/
#         sub-3239413/
#         sub-3262042/
#         sub-3269608/
#         sub-3306863/
#         sub-3320367/
#         sub-3348989/
#         sub-3378296/
#         sub-3390312/
#         sub-3407871/
#         sub-3504058/
#         sub-3520880/
#         sub-3554582/
#         sub-3559087/
#         sub-3587000/
#         sub-3593327/
#         sub-3605062/
#         sub-3672854/
#         sub-3707771/
#         sub-3732101/
#         sub-3739175/
#         sub-3767334/
#         sub-3809753/
#         sub-3834703/
#         sub-3889095/
#         sub-3967265/
#         sub-3976121/
#         sub-3983607/
#         sub-4028266/
#         sub-4053836/
#         sub-4091983/
#         sub-4095748/
#         sub-4125514/
#         sub-4256491/
#         sub-4334113/
#         sub-4383707/
#         sub-4475709/
#         sub-4921428/
#         sub-5150328/
#         sub-5193577/
#         sub-5600820/
#         sub-6187322/
#         sub-6550938/
#         sub-7093319/
#         sub-7135128/
#         sub-7390867/
#         sub-7591533/
#         sub-7947495/
#         sub-8328877/
#         sub-8463326/
#         sub-8838009/
#         sub-9093997/
# NeuroIMAGE/
#     NeuroIMAGE/
#         anat_processed_paths.csv
#         dataset_description.json
#         filtered_participants.tsv
#         filtered_paths.csv
#         missing_participants_ids.csv
#         ... and 6 more
#         sub-1017176/
#             normalized_resampled_128_sub-1017176_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1017176_T1_biascorr_brain.nii
#             resampled_128_sub-1017176_T1_biascorr_brain.nii
#             resampled_224_sub-1017176_T1_biascorr_brain.nii
#             sub-1017176_T1_biascorr_brain.nii
#         sub-1125505/
#             normalized_resampled_128_sub-1125505_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1125505_T1_biascorr_brain.nii
#             resampled_128_sub-1125505_T1_biascorr_brain.nii
#             resampled_224_sub-1125505_T1_biascorr_brain.nii
#             sub-1125505_T1_biascorr_brain.nii
#         sub-1208586/
#             normalized_resampled_128_sub-1208586_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1208586_T1_biascorr_brain.nii
#             resampled_128_sub-1208586_T1_biascorr_brain.nii
#             resampled_224_sub-1208586_T1_biascorr_brain.nii
#             sub-1208586_T1_biascorr_brain.nii
#         sub-1312097/
#             normalized_resampled_128_sub-1312097_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1312097_T1_biascorr_brain.nii
#             resampled_128_sub-1312097_T1_biascorr_brain.nii
#             resampled_224_sub-1312097_T1_biascorr_brain.nii
#             sub-1312097_T1_biascorr_brain.nii
#         sub-1411495/
#             normalized_resampled_128_sub-1411495_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1411495_T1_biascorr_brain.nii
#             resampled_128_sub-1411495_T1_biascorr_brain.nii
#             resampled_224_sub-1411495_T1_biascorr_brain.nii
#             sub-1411495_T1_biascorr_brain.nii
#         sub-1438162/
#             normalized_resampled_128_sub-1438162_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1438162_T1_biascorr_brain.nii
#             resampled_128_sub-1438162_T1_biascorr_brain.nii
#             resampled_224_sub-1438162_T1_biascorr_brain.nii
#             sub-1438162_T1_biascorr_brain.nii
#         sub-1538046/
#             normalized_resampled_128_sub-1538046_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1538046_T1_biascorr_brain.nii
#             resampled_128_sub-1538046_T1_biascorr_brain.nii
#             resampled_224_sub-1538046_T1_biascorr_brain.nii
#             sub-1538046_T1_biascorr_brain.nii
#         sub-1585708/
#             normalized_resampled_128_sub-1585708_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1585708_T1_biascorr_brain.nii
#             resampled_128_sub-1585708_T1_biascorr_brain.nii
#             resampled_224_sub-1585708_T1_biascorr_brain.nii
#             sub-1585708_T1_biascorr_brain.nii
#         sub-1588809/
#             normalized_resampled_128_sub-1588809_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1588809_T1_biascorr_brain.nii
#             resampled_128_sub-1588809_T1_biascorr_brain.nii
#             resampled_224_sub-1588809_T1_biascorr_brain.nii
#             sub-1588809_T1_biascorr_brain.nii
#         sub-2029723/
#             normalized_resampled_128_sub-2029723_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2029723_T1_biascorr_brain.nii
#             resampled_128_sub-2029723_T1_biascorr_brain.nii
#             resampled_224_sub-2029723_T1_biascorr_brain.nii
#             sub-2029723_T1_biascorr_brain.nii
#         sub-2074737/
#             normalized_resampled_128_sub-2074737_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2074737_T1_biascorr_brain.nii
#             resampled_128_sub-2074737_T1_biascorr_brain.nii
#             resampled_224_sub-2074737_T1_biascorr_brain.nii
#             sub-2074737_T1_biascorr_brain.nii
#         sub-2352986/
#             normalized_resampled_128_sub-2352986_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2352986_T1_biascorr_brain.nii
#             resampled_128_sub-2352986_T1_biascorr_brain.nii
#             resampled_224_sub-2352986_T1_biascorr_brain.nii
#             sub-2352986_T1_biascorr_brain.nii
#         sub-2419464/
#             normalized_resampled_128_sub-2419464_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2419464_T1_biascorr_brain.nii
#             resampled_128_sub-2419464_T1_biascorr_brain.nii
#             resampled_224_sub-2419464_T1_biascorr_brain.nii
#             sub-2419464_T1_biascorr_brain.nii
#         sub-2574674/
#             normalized_resampled_128_sub-2574674_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2574674_T1_biascorr_brain.nii
#             resampled_128_sub-2574674_T1_biascorr_brain.nii
#             resampled_224_sub-2574674_T1_biascorr_brain.nii
#             sub-2574674_T1_biascorr_brain.nii
#         sub-2671604/
#             normalized_resampled_128_sub-2671604_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2671604_T1_biascorr_brain.nii
#             resampled_128_sub-2671604_T1_biascorr_brain.nii
#             resampled_224_sub-2671604_T1_biascorr_brain.nii
#             sub-2671604_T1_biascorr_brain.nii
#         sub-27000/
#             normalized_resampled_128_sub-27000_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27000_T1_biascorr_brain.nii
#             resampled_128_sub-27000_T1_biascorr_brain.nii
#             resampled_224_sub-27000_T1_biascorr_brain.nii
#             sub-27000_T1_biascorr_brain.nii
#         sub-27003/
#             normalized_resampled_128_sub-27003_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27003_T1_biascorr_brain.nii
#             resampled_128_sub-27003_T1_biascorr_brain.nii
#             resampled_224_sub-27003_T1_biascorr_brain.nii
#             sub-27003_T1_biascorr_brain.nii
#         sub-27004/
#             normalized_resampled_128_sub-27004_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27004_T1_biascorr_brain.nii
#             resampled_128_sub-27004_T1_biascorr_brain.nii
#             resampled_224_sub-27004_T1_biascorr_brain.nii
#             sub-27004_T1_biascorr_brain.nii
#         sub-27005/
#             normalized_resampled_128_sub-27005_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27005_T1_biascorr_brain.nii
#             resampled_128_sub-27005_T1_biascorr_brain.nii
#             resampled_224_sub-27005_T1_biascorr_brain.nii
#             sub-27005_T1_biascorr_brain.nii
#         sub-27007/
#             normalized_resampled_128_sub-27007_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27007_T1_biascorr_brain.nii
#             resampled_128_sub-27007_T1_biascorr_brain.nii
#             resampled_224_sub-27007_T1_biascorr_brain.nii
#             sub-27007_T1_biascorr_brain.nii
#         sub-27008/
#             normalized_resampled_128_sub-27008_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27008_T1_biascorr_brain.nii
#             resampled_128_sub-27008_T1_biascorr_brain.nii
#             resampled_224_sub-27008_T1_biascorr_brain.nii
#             sub-27008_T1_biascorr_brain.nii
#         sub-27010/
#             normalized_resampled_128_sub-27010_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27010_T1_biascorr_brain.nii
#             resampled_128_sub-27010_T1_biascorr_brain.nii
#             resampled_224_sub-27010_T1_biascorr_brain.nii
#             sub-27010_T1_biascorr_brain.nii
#         sub-27011/
#             normalized_resampled_128_sub-27011_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27011_T1_biascorr_brain.nii
#             resampled_128_sub-27011_T1_biascorr_brain.nii
#             resampled_224_sub-27011_T1_biascorr_brain.nii
#             sub-27011_T1_biascorr_brain.nii
#         sub-27012/
#             normalized_resampled_128_sub-27012_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27012_T1_biascorr_brain.nii
#             resampled_128_sub-27012_T1_biascorr_brain.nii
#             resampled_224_sub-27012_T1_biascorr_brain.nii
#             sub-27012_T1_biascorr_brain.nii
#         sub-27015/
#             normalized_resampled_128_sub-27015_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27015_T1_biascorr_brain.nii
#             resampled_128_sub-27015_T1_biascorr_brain.nii
#             resampled_224_sub-27015_T1_biascorr_brain.nii
#             sub-27015_T1_biascorr_brain.nii
#         sub-27016/
#             normalized_resampled_128_sub-27016_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27016_T1_biascorr_brain.nii
#             resampled_128_sub-27016_T1_biascorr_brain.nii
#             resampled_224_sub-27016_T1_biascorr_brain.nii
#             sub-27016_T1_biascorr_brain.nii
#         sub-27017/
#             normalized_resampled_128_sub-27017_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27017_T1_biascorr_brain.nii
#             resampled_128_sub-27017_T1_biascorr_brain.nii
#             resampled_224_sub-27017_T1_biascorr_brain.nii
#             sub-27017_T1_biascorr_brain.nii
#         sub-27018/
#             normalized_resampled_128_sub-27018_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27018_T1_biascorr_brain.nii
#             resampled_128_sub-27018_T1_biascorr_brain.nii
#             resampled_224_sub-27018_T1_biascorr_brain.nii
#             sub-27018_T1_biascorr_brain.nii
#         sub-27020/
#             normalized_resampled_128_sub-27020_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27020_T1_biascorr_brain.nii
#             resampled_128_sub-27020_T1_biascorr_brain.nii
#             resampled_224_sub-27020_T1_biascorr_brain.nii
#             sub-27020_T1_biascorr_brain.nii
#         sub-27021/
#             normalized_resampled_128_sub-27021_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27021_T1_biascorr_brain.nii
#             resampled_128_sub-27021_T1_biascorr_brain.nii
#             resampled_224_sub-27021_T1_biascorr_brain.nii
#             sub-27021_T1_biascorr_brain.nii
#         sub-27022/
#             normalized_resampled_128_sub-27022_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27022_T1_biascorr_brain.nii
#             resampled_128_sub-27022_T1_biascorr_brain.nii
#             resampled_224_sub-27022_T1_biascorr_brain.nii
#             sub-27022_T1_biascorr_brain.nii
#         sub-27023/
#             normalized_resampled_128_sub-27023_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27023_T1_biascorr_brain.nii
#             resampled_128_sub-27023_T1_biascorr_brain.nii
#             resampled_224_sub-27023_T1_biascorr_brain.nii
#             sub-27023_T1_biascorr_brain.nii
#         sub-27024/
#             normalized_resampled_128_sub-27024_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27024_T1_biascorr_brain.nii
#             resampled_128_sub-27024_T1_biascorr_brain.nii
#             resampled_224_sub-27024_T1_biascorr_brain.nii
#             sub-27024_T1_biascorr_brain.nii
#         sub-27025/
#             normalized_resampled_128_sub-27025_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27025_T1_biascorr_brain.nii
#             resampled_128_sub-27025_T1_biascorr_brain.nii
#             resampled_224_sub-27025_T1_biascorr_brain.nii
#             sub-27025_T1_biascorr_brain.nii
#         sub-27026/
#             normalized_resampled_128_sub-27026_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27026_T1_biascorr_brain.nii
#             resampled_128_sub-27026_T1_biascorr_brain.nii
#             resampled_224_sub-27026_T1_biascorr_brain.nii
#             sub-27026_T1_biascorr_brain.nii
#         sub-27028/
#             normalized_resampled_128_sub-27028_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27028_T1_biascorr_brain.nii
#             resampled_128_sub-27028_T1_biascorr_brain.nii
#             resampled_224_sub-27028_T1_biascorr_brain.nii
#             sub-27028_T1_biascorr_brain.nii
#         sub-27034/
#             normalized_resampled_128_sub-27034_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27034_T1_biascorr_brain.nii
#             resampled_128_sub-27034_T1_biascorr_brain.nii
#             resampled_224_sub-27034_T1_biascorr_brain.nii
#             sub-27034_T1_biascorr_brain.nii
#         sub-27037/
#             normalized_resampled_128_sub-27037_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27037_T1_biascorr_brain.nii
#             resampled_128_sub-27037_T1_biascorr_brain.nii
#             resampled_224_sub-27037_T1_biascorr_brain.nii
#             sub-27037_T1_biascorr_brain.nii
#         sub-27040/
#             normalized_resampled_128_sub-27040_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27040_T1_biascorr_brain.nii
#             resampled_128_sub-27040_T1_biascorr_brain.nii
#             resampled_224_sub-27040_T1_biascorr_brain.nii
#             sub-27040_T1_biascorr_brain.nii
#         sub-27042/
#             normalized_resampled_128_sub-27042_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-27042_T1_biascorr_brain.nii
#             resampled_128_sub-27042_T1_biascorr_brain.nii
#             resampled_224_sub-27042_T1_biascorr_brain.nii
#             sub-27042_T1_biascorr_brain.nii
#         sub-2756846/
#             normalized_resampled_128_sub-2756846_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2756846_T1_biascorr_brain.nii
#             resampled_128_sub-2756846_T1_biascorr_brain.nii
#             resampled_224_sub-2756846_T1_biascorr_brain.nii
#             sub-2756846_T1_biascorr_brain.nii
#         sub-2876903/
#             normalized_resampled_128_sub-2876903_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2876903_T1_biascorr_brain.nii
#             resampled_128_sub-2876903_T1_biascorr_brain.nii
#             resampled_224_sub-2876903_T1_biascorr_brain.nii
#             sub-2876903_T1_biascorr_brain.nii
#         sub-2961243/
#             normalized_resampled_128_sub-2961243_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2961243_T1_biascorr_brain.nii
#             resampled_128_sub-2961243_T1_biascorr_brain.nii
#             resampled_224_sub-2961243_T1_biascorr_brain.nii
#             sub-2961243_T1_biascorr_brain.nii
#         sub-3007585/
#             normalized_resampled_128_sub-3007585_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3007585_T1_biascorr_brain.nii
#             resampled_128_sub-3007585_T1_biascorr_brain.nii
#             resampled_224_sub-3007585_T1_biascorr_brain.nii
#             sub-3007585_T1_biascorr_brain.nii
#         sub-3048588/
#             normalized_resampled_128_sub-3048588_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3048588_T1_biascorr_brain.nii
#             resampled_128_sub-3048588_T1_biascorr_brain.nii
#             resampled_224_sub-3048588_T1_biascorr_brain.nii
#             sub-3048588_T1_biascorr_brain.nii
#         sub-3082137/
#             normalized_resampled_128_sub-3082137_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3082137_T1_biascorr_brain.nii
#             resampled_128_sub-3082137_T1_biascorr_brain.nii
#             resampled_224_sub-3082137_T1_biascorr_brain.nii
#             sub-3082137_T1_biascorr_brain.nii
#         sub-3108222/
#             normalized_resampled_128_sub-3108222_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3108222_T1_biascorr_brain.nii
#             resampled_128_sub-3108222_T1_biascorr_brain.nii
#             resampled_224_sub-3108222_T1_biascorr_brain.nii
#             sub-3108222_T1_biascorr_brain.nii
#         sub-3190461/
#             normalized_resampled_128_sub-3190461_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3190461_T1_biascorr_brain.nii
#             resampled_128_sub-3190461_T1_biascorr_brain.nii
#             resampled_224_sub-3190461_T1_biascorr_brain.nii
#             sub-3190461_T1_biascorr_brain.nii
#         sub-3304956/
#             normalized_resampled_128_sub-3304956_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3304956_T1_biascorr_brain.nii
#             resampled_128_sub-3304956_T1_biascorr_brain.nii
#             resampled_224_sub-3304956_T1_biascorr_brain.nii
#             sub-3304956_T1_biascorr_brain.nii
#         sub-3322144/
#             normalized_resampled_128_sub-3322144_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3322144_T1_biascorr_brain.nii
#             resampled_128_sub-3322144_T1_biascorr_brain.nii
#             resampled_224_sub-3322144_T1_biascorr_brain.nii
#             sub-3322144_T1_biascorr_brain.nii
#         sub-3449233/
#             normalized_resampled_128_sub-3449233_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3449233_T1_biascorr_brain.nii
#             resampled_128_sub-3449233_T1_biascorr_brain.nii
#             resampled_224_sub-3449233_T1_biascorr_brain.nii
#             sub-3449233_T1_biascorr_brain.nii
#         sub-3515506/
#             normalized_resampled_128_sub-3515506_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3515506_T1_biascorr_brain.nii
#             resampled_128_sub-3515506_T1_biascorr_brain.nii
#             resampled_224_sub-3515506_T1_biascorr_brain.nii
#             sub-3515506_T1_biascorr_brain.nii
#         sub-3566449/
#             normalized_resampled_128_sub-3566449_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3566449_T1_biascorr_brain.nii
#             resampled_128_sub-3566449_T1_biascorr_brain.nii
#             resampled_224_sub-3566449_T1_biascorr_brain.nii
#             sub-3566449_T1_biascorr_brain.nii
#         sub-3808273/
#             normalized_resampled_128_sub-3808273_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3808273_T1_biascorr_brain.nii
#             resampled_128_sub-3808273_T1_biascorr_brain.nii
#             resampled_224_sub-3808273_T1_biascorr_brain.nii
#             sub-3808273_T1_biascorr_brain.nii
#         sub-3858891/
#             normalized_resampled_128_sub-3858891_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3858891_T1_biascorr_brain.nii
#             resampled_128_sub-3858891_T1_biascorr_brain.nii
#             resampled_224_sub-3858891_T1_biascorr_brain.nii
#             sub-3858891_T1_biascorr_brain.nii
#         sub-3888614/
#             normalized_resampled_128_sub-3888614_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3888614_T1_biascorr_brain.nii
#             resampled_128_sub-3888614_T1_biascorr_brain.nii
#             resampled_224_sub-3888614_T1_biascorr_brain.nii
#             sub-3888614_T1_biascorr_brain.nii
#         sub-3941358/
#             normalized_resampled_128_sub-3941358_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3941358_T1_biascorr_brain.nii
#             resampled_128_sub-3941358_T1_biascorr_brain.nii
#             resampled_224_sub-3941358_T1_biascorr_brain.nii
#             sub-3941358_T1_biascorr_brain.nii
#         sub-3959823/
#             normalized_resampled_128_sub-3959823_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3959823_T1_biascorr_brain.nii
#             resampled_128_sub-3959823_T1_biascorr_brain.nii
#             resampled_224_sub-3959823_T1_biascorr_brain.nii
#             sub-3959823_T1_biascorr_brain.nii
#         sub-3980079/
#             normalized_resampled_128_sub-3980079_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3980079_T1_biascorr_brain.nii
#             resampled_128_sub-3980079_T1_biascorr_brain.nii
#             resampled_224_sub-3980079_T1_biascorr_brain.nii
#             sub-3980079_T1_biascorr_brain.nii
#         sub-4020830/
#             normalized_resampled_128_sub-4020830_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-4020830_T1_biascorr_brain.nii
#             resampled_128_sub-4020830_T1_biascorr_brain.nii
#             resampled_224_sub-4020830_T1_biascorr_brain.nii
#             sub-4020830_T1_biascorr_brain.nii
#         sub-4134561/
#             normalized_resampled_128_sub-4134561_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-4134561_T1_biascorr_brain.nii
#             resampled_128_sub-4134561_T1_biascorr_brain.nii
#             resampled_224_sub-4134561_T1_biascorr_brain.nii
#             sub-4134561_T1_biascorr_brain.nii
#         sub-4239636/
#             normalized_resampled_128_sub-4239636_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-4239636_T1_biascorr_brain.nii
#             resampled_128_sub-4239636_T1_biascorr_brain.nii
#             resampled_224_sub-4239636_T1_biascorr_brain.nii
#             sub-4239636_T1_biascorr_brain.nii
#         sub-4285031/
#             normalized_resampled_128_sub-4285031_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-4285031_T1_biascorr_brain.nii
#             resampled_128_sub-4285031_T1_biascorr_brain.nii
#             resampled_224_sub-4285031_T1_biascorr_brain.nii
#             sub-4285031_T1_biascorr_brain.nii
#         sub-4919979/
#             normalized_resampled_128_sub-4919979_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-4919979_T1_biascorr_brain.nii
#             resampled_128_sub-4919979_T1_biascorr_brain.nii
#             resampled_224_sub-4919979_T1_biascorr_brain.nii
#             sub-4919979_T1_biascorr_brain.nii
#         sub-5045355/
#             normalized_resampled_128_sub-5045355_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-5045355_T1_biascorr_brain.nii
#             resampled_128_sub-5045355_T1_biascorr_brain.nii
#             resampled_224_sub-5045355_T1_biascorr_brain.nii
#             sub-5045355_T1_biascorr_brain.nii
#         sub-6115230/
#             normalized_resampled_128_sub-6115230_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-6115230_T1_biascorr_brain.nii
#             resampled_128_sub-6115230_T1_biascorr_brain.nii
#             resampled_224_sub-6115230_T1_biascorr_brain.nii
#             sub-6115230_T1_biascorr_brain.nii
#         sub-7339173/
#             normalized_resampled_128_sub-7339173_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-7339173_T1_biascorr_brain.nii
#             resampled_128_sub-7339173_T1_biascorr_brain.nii
#             resampled_224_sub-7339173_T1_biascorr_brain.nii
#             sub-7339173_T1_biascorr_brain.nii
#         sub-7446626/
#             normalized_resampled_128_sub-7446626_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-7446626_T1_biascorr_brain.nii
#             resampled_128_sub-7446626_T1_biascorr_brain.nii
#             resampled_224_sub-7446626_T1_biascorr_brain.nii
#             sub-7446626_T1_biascorr_brain.nii
#         sub-7504392/
#             normalized_resampled_128_sub-7504392_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-7504392_T1_biascorr_brain.nii
#             resampled_128_sub-7504392_T1_biascorr_brain.nii
#             resampled_224_sub-7504392_T1_biascorr_brain.nii
#             sub-7504392_T1_biascorr_brain.nii
#         sub-8387093/
#             normalized_resampled_128_sub-8387093_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-8387093_T1_biascorr_brain.nii
#             resampled_128_sub-8387093_T1_biascorr_brain.nii
#             resampled_224_sub-8387093_T1_biascorr_brain.nii
#             sub-8387093_T1_biascorr_brain.nii
#         sub-8409791/
#             normalized_resampled_128_sub-8409791_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-8409791_T1_biascorr_brain.nii
#             resampled_128_sub-8409791_T1_biascorr_brain.nii
#             resampled_224_sub-8409791_T1_biascorr_brain.nii
#             sub-8409791_T1_biascorr_brain.nii
#         sub-8991934/
#             normalized_resampled_128_sub-8991934_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-8991934_T1_biascorr_brain.nii
#             resampled_128_sub-8991934_T1_biascorr_brain.nii
#             resampled_224_sub-8991934_T1_biascorr_brain.nii
#             sub-8991934_T1_biascorr_brain.nii
#         sub-9956994/
#             normalized_resampled_128_sub-9956994_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-9956994_T1_biascorr_brain.nii
#             resampled_128_sub-9956994_T1_biascorr_brain.nii
#             resampled_224_sub-9956994_T1_biascorr_brain.nii
#             sub-9956994_T1_biascorr_brain.nii
# KKI/
#     KKI/
#         anat_processed_paths.csv
#         dataset_description.json
#         filtered_participants.tsv
#         filtered_paths.csv
#         missing_participants_ids.csv
#         ... and 7 more
#         sub-1018959/
#             normalized_resampled_128_sub-1018959_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1018959_T1_biascorr_brain.nii
#             resampled_128_sub-1018959_T1_biascorr_brain.nii
#             resampled_224_sub-1018959_T1_biascorr_brain.nii
#             sub-1018959_T1_biascorr_brain.nii
#         sub-1019436/
#             normalized_resampled_128_sub-1019436_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1019436_T1_biascorr_brain.nii
#             resampled_128_sub-1019436_T1_biascorr_brain.nii
#             resampled_224_sub-1019436_T1_biascorr_brain.nii
#             sub-1019436_T1_biascorr_brain.nii
#         sub-1043241/
#             normalized_resampled_128_sub-1043241_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1043241_T1_biascorr_brain.nii
#             resampled_128_sub-1043241_T1_biascorr_brain.nii
#             resampled_224_sub-1043241_T1_biascorr_brain.nii
#             sub-1043241_T1_biascorr_brain.nii
#         sub-1266183/
#             normalized_resampled_128_sub-1266183_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1266183_T1_biascorr_brain.nii
#             resampled_128_sub-1266183_T1_biascorr_brain.nii
#             resampled_224_sub-1266183_T1_biascorr_brain.nii
#             sub-1266183_T1_biascorr_brain.nii
#         sub-1535233/
#             normalized_resampled_128_sub-1535233_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1535233_T1_biascorr_brain.nii
#             resampled_128_sub-1535233_T1_biascorr_brain.nii
#             resampled_224_sub-1535233_T1_biascorr_brain.nii
#             sub-1535233_T1_biascorr_brain.nii
#         sub-1541812/
#             normalized_resampled_128_sub-1541812_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1541812_T1_biascorr_brain.nii
#             resampled_128_sub-1541812_T1_biascorr_brain.nii
#             resampled_224_sub-1541812_T1_biascorr_brain.nii
#             sub-1541812_T1_biascorr_brain.nii
#         sub-1577042/
#             normalized_resampled_128_sub-1577042_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1577042_T1_biascorr_brain.nii
#             resampled_128_sub-1577042_T1_biascorr_brain.nii
#             resampled_224_sub-1577042_T1_biascorr_brain.nii
#             sub-1577042_T1_biascorr_brain.nii
#         sub-1594156/
#             normalized_resampled_128_sub-1594156_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1594156_T1_biascorr_brain.nii
#             resampled_128_sub-1594156_T1_biascorr_brain.nii
#             resampled_224_sub-1594156_T1_biascorr_brain.nii
#             sub-1594156_T1_biascorr_brain.nii
#         sub-1623716/
#             normalized_resampled_128_sub-1623716_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1623716_T1_biascorr_brain.nii
#             resampled_128_sub-1623716_T1_biascorr_brain.nii
#             resampled_224_sub-1623716_T1_biascorr_brain.nii
#             sub-1623716_T1_biascorr_brain.nii
#         sub-1638334/
#             normalized_resampled_128_sub-1638334_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1638334_T1_biascorr_brain.nii
#             resampled_128_sub-1638334_T1_biascorr_brain.nii
#             resampled_224_sub-1638334_T1_biascorr_brain.nii
#             sub-1638334_T1_biascorr_brain.nii
#         sub-1652369/
#             normalized_resampled_128_sub-1652369_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1652369_T1_biascorr_brain.nii
#             resampled_128_sub-1652369_T1_biascorr_brain.nii
#             resampled_224_sub-1652369_T1_biascorr_brain.nii
#             sub-1652369_T1_biascorr_brain.nii
#         sub-1686265/
#             normalized_resampled_128_sub-1686265_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1686265_T1_biascorr_brain.nii
#             resampled_128_sub-1686265_T1_biascorr_brain.nii
#             resampled_224_sub-1686265_T1_biascorr_brain.nii
#             sub-1686265_T1_biascorr_brain.nii
#         sub-1692275/
#             normalized_resampled_128_sub-1692275_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1692275_T1_biascorr_brain.nii
#             resampled_128_sub-1692275_T1_biascorr_brain.nii
#             resampled_224_sub-1692275_T1_biascorr_brain.nii
#             sub-1692275_T1_biascorr_brain.nii
#         sub-1735881/
#             normalized_resampled_128_sub-1735881_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1735881_T1_biascorr_brain.nii
#             resampled_128_sub-1735881_T1_biascorr_brain.nii
#             resampled_224_sub-1735881_T1_biascorr_brain.nii
#             sub-1735881_T1_biascorr_brain.nii
#         sub-1779922/
#             normalized_resampled_128_sub-1779922_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1779922_T1_biascorr_brain.nii
#             resampled_128_sub-1779922_T1_biascorr_brain.nii
#             resampled_224_sub-1779922_T1_biascorr_brain.nii
#             sub-1779922_T1_biascorr_brain.nii
#         sub-1842819/
#             normalized_resampled_128_sub-1842819_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1842819_T1_biascorr_brain.nii
#             resampled_128_sub-1842819_T1_biascorr_brain.nii
#             resampled_224_sub-1842819_T1_biascorr_brain.nii
#             sub-1842819_T1_biascorr_brain.nii
#         sub-1846346/
#             normalized_resampled_128_sub-1846346_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1846346_T1_biascorr_brain.nii
#             resampled_128_sub-1846346_T1_biascorr_brain.nii
#             resampled_224_sub-1846346_T1_biascorr_brain.nii
#             sub-1846346_T1_biascorr_brain.nii
#         sub-1873761/
#             normalized_resampled_128_sub-1873761_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-1873761_T1_biascorr_brain.nii
#             resampled_128_sub-1873761_T1_biascorr_brain.nii
#             resampled_224_sub-1873761_T1_biascorr_brain.nii
#             sub-1873761_T1_biascorr_brain.nii
#         sub-1962503/
#             normalized_resampled_128_sub-1962503_T1_biascorr_brain.nii
# ...
#             resampled_128_sub-2572285_T1_biascorr_brain.nii
#             resampled_224_sub-2572285_T1_biascorr_brain.nii
#             sub-2572285_T1_biascorr_brain.nii
#         sub-2601925/
#             normalized_resampled_128_sub-2601925_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2601925_T1_biascorr_brain.nii
#             resampled_128_sub-2601925_T1_biascorr_brain.nii
#             resampled_224_sub-2601925_T1_biascorr_brain.nii
#             sub-2601925_T1_biascorr_brain.nii
#         sub-2618929/
#             normalized_resampled_128_sub-2618929_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2618929_T1_biascorr_brain.nii
#             resampled_128_sub-2618929_T1_biascorr_brain.nii
#             resampled_224_sub-2618929_T1_biascorr_brain.nii
#             sub-2618929_T1_biascorr_brain.nii
#         sub-2621228/
#             normalized_resampled_128_sub-2621228_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2621228_T1_biascorr_brain.nii
#             resampled_128_sub-2621228_T1_biascorr_brain.nii
#             resampled_224_sub-2621228_T1_biascorr_brain.nii
#             sub-2621228_T1_biascorr_brain.nii
#         sub-2640795/
#             normalized_resampled_128_sub-2640795_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2640795_T1_biascorr_brain.nii
#             resampled_128_sub-2640795_T1_biascorr_brain.nii
#             resampled_224_sub-2640795_T1_biascorr_brain.nii
#             sub-2640795_T1_biascorr_brain.nii
#         sub-2641332/
#             normalized_resampled_128_sub-2641332_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2641332_T1_biascorr_brain.nii
#             resampled_128_sub-2641332_T1_biascorr_brain.nii
#             resampled_224_sub-2641332_T1_biascorr_brain.nii
#             sub-2641332_T1_biascorr_brain.nii
#         sub-2703289/
#             normalized_resampled_128_sub-2703289_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2703289_T1_biascorr_brain.nii
#             resampled_128_sub-2703289_T1_biascorr_brain.nii
#             resampled_224_sub-2703289_T1_biascorr_brain.nii
#             sub-2703289_T1_biascorr_brain.nii
#         sub-2740232/
#             normalized_resampled_128_sub-2740232_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2740232_T1_biascorr_brain.nii
#             resampled_128_sub-2740232_T1_biascorr_brain.nii
#             resampled_224_sub-2740232_T1_biascorr_brain.nii
#             sub-2740232_T1_biascorr_brain.nii
#         sub-2822304/
#             normalized_resampled_128_sub-2822304_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2822304_T1_biascorr_brain.nii
#             resampled_128_sub-2822304_T1_biascorr_brain.nii
#             resampled_224_sub-2822304_T1_biascorr_brain.nii
#             sub-2822304_T1_biascorr_brain.nii
#         sub-2903997/
#             normalized_resampled_128_sub-2903997_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2903997_T1_biascorr_brain.nii
#             resampled_128_sub-2903997_T1_biascorr_brain.nii
#             resampled_224_sub-2903997_T1_biascorr_brain.nii
#             sub-2903997_T1_biascorr_brain.nii
#         sub-2917777/
#             normalized_resampled_128_sub-2917777_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2917777_T1_biascorr_brain.nii
#             resampled_128_sub-2917777_T1_biascorr_brain.nii
#             resampled_224_sub-2917777_T1_biascorr_brain.nii
#             sub-2917777_T1_biascorr_brain.nii
#         sub-2930625/
#             normalized_resampled_128_sub-2930625_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-2930625_T1_biascorr_brain.nii
#             resampled_128_sub-2930625_T1_biascorr_brain.nii
#             resampled_224_sub-2930625_T1_biascorr_brain.nii
#             sub-2930625_T1_biascorr_brain.nii
#         sub-3103809/
#             normalized_resampled_128_sub-3103809_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3103809_T1_biascorr_brain.nii
#             resampled_128_sub-3103809_T1_biascorr_brain.nii
#             resampled_224_sub-3103809_T1_biascorr_brain.nii
#             sub-3103809_T1_biascorr_brain.nii
#         sub-3119327/
#             normalized_resampled_128_sub-3119327_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3119327_T1_biascorr_brain.nii
#             resampled_128_sub-3119327_T1_biascorr_brain.nii
#             resampled_224_sub-3119327_T1_biascorr_brain.nii
#             sub-3119327_T1_biascorr_brain.nii
#         sub-3154996/
#             normalized_resampled_128_sub-3154996_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3154996_T1_biascorr_brain.nii
#             resampled_128_sub-3154996_T1_biascorr_brain.nii
#             resampled_224_sub-3154996_T1_biascorr_brain.nii
#             sub-3154996_T1_biascorr_brain.nii
#         sub-3160561/
#             normalized_resampled_128_sub-3160561_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3160561_T1_biascorr_brain.nii
#             resampled_128_sub-3160561_T1_biascorr_brain.nii
#             resampled_224_sub-3160561_T1_biascorr_brain.nii
#             sub-3160561_T1_biascorr_brain.nii
#         sub-3170319/
#             normalized_resampled_128_sub-3170319_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3170319_T1_biascorr_brain.nii
#             resampled_128_sub-3170319_T1_biascorr_brain.nii
#             resampled_224_sub-3170319_T1_biascorr_brain.nii
#             sub-3170319_T1_biascorr_brain.nii
#         sub-3310328/
#             normalized_resampled_128_sub-3310328_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3310328_T1_biascorr_brain.nii
#             resampled_128_sub-3310328_T1_biascorr_brain.nii
#             resampled_224_sub-3310328_T1_biascorr_brain.nii
#             sub-3310328_T1_biascorr_brain.nii
#         sub-3434578/
#             normalized_resampled_128_sub-3434578_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3434578_T1_biascorr_brain.nii
#             resampled_128_sub-3434578_T1_biascorr_brain.nii
#             resampled_224_sub-3434578_T1_biascorr_brain.nii
#             sub-3434578_T1_biascorr_brain.nii
#         sub-3486975/
#             normalized_resampled_128_sub-3486975_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3486975_T1_biascorr_brain.nii
#             resampled_128_sub-3486975_T1_biascorr_brain.nii
#             resampled_224_sub-3486975_T1_biascorr_brain.nii
#             sub-3486975_T1_biascorr_brain.nii
#         sub-3519022/
#             normalized_resampled_128_sub-3519022_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3519022_T1_biascorr_brain.nii
#             resampled_128_sub-3519022_T1_biascorr_brain.nii
#             resampled_224_sub-3519022_T1_biascorr_brain.nii
#             sub-3519022_T1_biascorr_brain.nii
#         sub-3611827/
#             normalized_resampled_128_sub-3611827_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3611827_T1_biascorr_brain.nii
#             resampled_128_sub-3611827_T1_biascorr_brain.nii
#             resampled_224_sub-3611827_T1_biascorr_brain.nii
#             sub-3611827_T1_biascorr_brain.nii
#         sub-3699991/
#             normalized_resampled_128_sub-3699991_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3699991_T1_biascorr_brain.nii
#             resampled_128_sub-3699991_T1_biascorr_brain.nii
#             resampled_224_sub-3699991_T1_biascorr_brain.nii
#             sub-3699991_T1_biascorr_brain.nii
#         sub-3713230/
#             normalized_resampled_128_sub-3713230_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3713230_T1_biascorr_brain.nii
#             resampled_128_sub-3713230_T1_biascorr_brain.nii
#             resampled_224_sub-3713230_T1_biascorr_brain.nii
#             sub-3713230_T1_biascorr_brain.nii
#         sub-3813783/
#             normalized_resampled_128_sub-3813783_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3813783_T1_biascorr_brain.nii
#             resampled_128_sub-3813783_T1_biascorr_brain.nii
#             resampled_224_sub-3813783_T1_biascorr_brain.nii
#             sub-3813783_T1_biascorr_brain.nii
#         sub-3884955/
#             normalized_resampled_128_sub-3884955_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3884955_T1_biascorr_brain.nii
#             resampled_128_sub-3884955_T1_biascorr_brain.nii
#             resampled_224_sub-3884955_T1_biascorr_brain.nii
#             sub-3884955_T1_biascorr_brain.nii
#         sub-3902469/
#             normalized_resampled_128_sub-3902469_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3902469_T1_biascorr_brain.nii
#             resampled_128_sub-3902469_T1_biascorr_brain.nii
#             resampled_224_sub-3902469_T1_biascorr_brain.nii
#             sub-3902469_T1_biascorr_brain.nii
#         sub-3912996/
#             normalized_resampled_128_sub-3912996_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3912996_T1_biascorr_brain.nii
#             resampled_128_sub-3912996_T1_biascorr_brain.nii
#             resampled_224_sub-3912996_T1_biascorr_brain.nii
#             sub-3912996_T1_biascorr_brain.nii
#         sub-3917422/
#             normalized_resampled_128_sub-3917422_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3917422_T1_biascorr_brain.nii
#             resampled_128_sub-3917422_T1_biascorr_brain.nii
#             resampled_224_sub-3917422_T1_biascorr_brain.nii
#             sub-3917422_T1_biascorr_brain.nii
#         sub-3972472/
#             normalized_resampled_128_sub-3972472_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3972472_T1_biascorr_brain.nii
#             resampled_128_sub-3972472_T1_biascorr_brain.nii
#             resampled_224_sub-3972472_T1_biascorr_brain.nii
#             sub-3972472_T1_biascorr_brain.nii
#         sub-3972956/
#             normalized_resampled_128_sub-3972956_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-3972956_T1_biascorr_brain.nii
#             resampled_128_sub-3972956_T1_biascorr_brain.nii
#             resampled_224_sub-3972956_T1_biascorr_brain.nii
#             sub-3972956_T1_biascorr_brain.nii
#         sub-4104523/
#             normalized_resampled_128_sub-4104523_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-4104523_T1_biascorr_brain.nii
#             resampled_128_sub-4104523_T1_biascorr_brain.nii
#             resampled_224_sub-4104523_T1_biascorr_brain.nii
#             sub-4104523_T1_biascorr_brain.nii
#         sub-4154182/
#             normalized_resampled_128_sub-4154182_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-4154182_T1_biascorr_brain.nii
#             resampled_128_sub-4154182_T1_biascorr_brain.nii
#             resampled_224_sub-4154182_T1_biascorr_brain.nii
#             sub-4154182_T1_biascorr_brain.nii
#         sub-4275075/
#             normalized_resampled_128_sub-4275075_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-4275075_T1_biascorr_brain.nii
#             resampled_128_sub-4275075_T1_biascorr_brain.nii
#             resampled_224_sub-4275075_T1_biascorr_brain.nii
#             sub-4275075_T1_biascorr_brain.nii
#         sub-4362730/
#             normalized_resampled_128_sub-4362730_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-4362730_T1_biascorr_brain.nii
#             resampled_128_sub-4362730_T1_biascorr_brain.nii
#             resampled_224_sub-4362730_T1_biascorr_brain.nii
#             sub-4362730_T1_biascorr_brain.nii
#         sub-4601682/
#             normalized_resampled_128_sub-4601682_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-4601682_T1_biascorr_brain.nii
#             resampled_128_sub-4601682_T1_biascorr_brain.nii
#             resampled_224_sub-4601682_T1_biascorr_brain.nii
#             sub-4601682_T1_biascorr_brain.nii
#         sub-5216908/
#             normalized_resampled_128_sub-5216908_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-5216908_T1_biascorr_brain.nii
#             resampled_128_sub-5216908_T1_biascorr_brain.nii
#             resampled_224_sub-5216908_T1_biascorr_brain.nii
#             sub-5216908_T1_biascorr_brain.nii
#         sub-6346605/
#             normalized_resampled_128_sub-6346605_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-6346605_T1_biascorr_brain.nii
#             resampled_128_sub-6346605_T1_biascorr_brain.nii
#             resampled_224_sub-6346605_T1_biascorr_brain.nii
#             sub-6346605_T1_biascorr_brain.nii
#         sub-6453038/
#             normalized_resampled_128_sub-6453038_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-6453038_T1_biascorr_brain.nii
#             resampled_128_sub-6453038_T1_biascorr_brain.nii
#             resampled_224_sub-6453038_T1_biascorr_brain.nii
#             sub-6453038_T1_biascorr_brain.nii
#         sub-7129258/
#             normalized_resampled_128_sub-7129258_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-7129258_T1_biascorr_brain.nii
#             resampled_128_sub-7129258_T1_biascorr_brain.nii
#             resampled_224_sub-7129258_T1_biascorr_brain.nii
#             sub-7129258_T1_biascorr_brain.nii
#         sub-7415617/
#             normalized_resampled_128_sub-7415617_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-7415617_T1_biascorr_brain.nii
#             resampled_128_sub-7415617_T1_biascorr_brain.nii
#             resampled_224_sub-7415617_T1_biascorr_brain.nii
#             sub-7415617_T1_biascorr_brain.nii
#         sub-7774305/
#             normalized_resampled_128_sub-7774305_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-7774305_T1_biascorr_brain.nii
#             resampled_128_sub-7774305_T1_biascorr_brain.nii
#             resampled_224_sub-7774305_T1_biascorr_brain.nii
#             sub-7774305_T1_biascorr_brain.nii
#         sub-8083695/
#             normalized_resampled_128_sub-8083695_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-8083695_T1_biascorr_brain.nii
#             resampled_128_sub-8083695_T1_biascorr_brain.nii
#             resampled_224_sub-8083695_T1_biascorr_brain.nii
#             sub-8083695_T1_biascorr_brain.nii
#         sub-8263351/
#             normalized_resampled_128_sub-8263351_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-8263351_T1_biascorr_brain.nii
#             resampled_128_sub-8263351_T1_biascorr_brain.nii
#             resampled_224_sub-8263351_T1_biascorr_brain.nii
#             sub-8263351_T1_biascorr_brain.nii
#         sub-8337695/
#             normalized_resampled_128_sub-8337695_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-8337695_T1_biascorr_brain.nii
#             resampled_128_sub-8337695_T1_biascorr_brain.nii
#             resampled_224_sub-8337695_T1_biascorr_brain.nii
#             sub-8337695_T1_biascorr_brain.nii
#         sub-8432725/
#             normalized_resampled_128_sub-8432725_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-8432725_T1_biascorr_brain.nii
#             resampled_128_sub-8432725_T1_biascorr_brain.nii
#             resampled_224_sub-8432725_T1_biascorr_brain.nii
#             sub-8432725_T1_biascorr_brain.nii
#         sub-8628223/
#             normalized_resampled_128_sub-8628223_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-8628223_T1_biascorr_brain.nii
#             resampled_128_sub-8628223_T1_biascorr_brain.nii
#             resampled_224_sub-8628223_T1_biascorr_brain.nii
#             sub-8628223_T1_biascorr_brain.nii
#         sub-8658218/
#             normalized_resampled_128_sub-8658218_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-8658218_T1_biascorr_brain.nii
#             resampled_128_sub-8658218_T1_biascorr_brain.nii
#             resampled_224_sub-8658218_T1_biascorr_brain.nii
#             sub-8658218_T1_biascorr_brain.nii
#         sub-9922944/
#             normalized_resampled_128_sub-9922944_T1_biascorr_brain.nii
#             normalized_resampled_224_sub-9922944_T1_biascorr_brain.nii
#             resampled_128_sub-9922944_T1_biascorr_brain.nii
#             resampled_224_sub-9922944_T1_biascorr_brain.nii
#             sub-9922944_T1_biascorr_brain.nii

# %%
def find_t1_image_path(subject_id, site):
    """Find the T1-weighted structural image path"""
    site_folder = {
        'Peking': 'Peking_1/Peking_1',
        'NeuroIMAGE': 'NeuroIMAGE/NeuroIMAGE',
        'KKI': 'KKI/KKI'
    }.get(site)

    # Try multiple naming patterns
    patterns = [
        f"{base_path}/{site_folder}/sub-{subject_id}/sub-{subject_id}_T1_biascorr_brain.nii",
        f"{base_path}/{site_folder}/sub-{subject_id}/normalized_resampled_128_sub-{subject_id}_T1_biascorr_brain.nii",
        f"{base_path}/{site_folder}/sub-{subject_id}/resampled_128_sub-{subject_id}_T1_biascorr_brain.nii"
    ]

    for path in patterns:
        if os.path.exists(path):
            return path
    return None

# Test with sample subjects
print("\nTesting T1 image paths:")
sample_subjects = pheno_data.sample(5)
for _, row in sample_subjects.iterrows():
    path = find_t1_image_path(str(row['subject']).strip(), row['site'])
    if path:
        print(f"✓ Found: {row['site']} subject {row['subject']} at {path}")
    else:
        print(f"✗ Missing: {row['site']} subject {row['subject']}")

# Create image dataframe with T1 paths
image_df = pheno_data.copy()
image_df['image_path'] = image_df.apply(
    lambda row: find_t1_image_path(str(row['subject']).strip(), row['site']),
    axis=1
)

# Remove subjects without images
image_df = image_df.dropna(subset=['image_path'])
print(f"\nFound {len(image_df)} subjects with T1 images")
# Out:
# Testing T1 image paths:
# ✓ Found: KKI subject 4104523 at /content/drive/MyDrive/ADHD1//KKI/KKI/sub-4104523/sub-4104523_T1_biascorr_brain.nii
# ✓ Found: KKI subject 9922944 at /content/drive/MyDrive/ADHD1//KKI/KKI/sub-9922944/sub-9922944_T1_biascorr_brain.nii
# ✗ Missing: Peking subject 3983607
# ✗ Missing: Peking subject 3262042
# ✗ Missing: Peking subject 3889095
#
# Found 141 subjects with T1 images
